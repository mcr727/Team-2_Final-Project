# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mpld3

# File to Load (Remember to Change These)
file_to_load = "cleaned_posts.csv"

# Read Purchasing File and store into Pandas data frame
mb_types = pd.read_csv(file_to_load)
mb_types_df = pd.DataFrame(mb_types)
mb_types_df.head()
# Out:
#   label                                               post
# 0  INFJ  What has been the most life-changing experienc...
# 1  INFJ               May the PerC Experience immerse you.
# 2  INFJ  Hello ENFJ7. Sorry to hear of your distress. I...
# 3  INFJ                                 Welcome and stuff.
# 4  INFJ  Prozac, wellbrutin, at least thirty minutes of...

# %%
UniqueLabel = len(mb_types_df["label"].unique())
UniqueLabel = pd.DataFrame({"Label Count": [UniqueLabel]})
UniqueLabel
# Out:
#    Label Count
# 0           16

# %%
mb_types_df.rename(columns = {'label':'Type'}, inplace = True) 
mb_types_df.head()
# Out:
#    Type                                               post
# 0  INFJ  What has been the most life-changing experienc...
# 1  INFJ               May the PerC Experience immerse you.
# 2  INFJ  Hello ENFJ7. Sorry to hear of your distress. I...
# 3  INFJ                                 Welcome and stuff.
# 4  INFJ  Prozac, wellbrutin, at least thirty minutes of...

# %%
#Label Type Count
mb_df=mb_types_df.groupby(['Type'],as_index=False).size()
mb_df
# Out:
# Type
# ENFJ     8814
# ENFP    31112
# ENTJ    10690
# ENTP    32071
# ESFJ     1971
# ESFP     2087
# ESTJ     1826
# ESTP     4084
# INFJ    67638
# INFP    83569
# INTJ    49400
# INTP    59144
# ISFJ     7585
# ISFP    11928
# ISTJ     9290
# ISTP    15314
# dtype: int64

# %%
mb_types_df.groupby('Type').agg('count').reset_index()
# Out:
#     Type   post
# 0   ENFJ   8814
# 1   ENFP  31112
# 2   ENTJ  10690
# 3   ENTP  32071
# 4   ESFJ   1971
# 5   ESFP   2087
# 6   ESTJ   1826
# 7   ESTP   4084
# 8   INFJ  67638
# 9   INFP  83569
# 10  INTJ  49400
# 11  INTP  59144
# 12  ISFJ   7585
# 13  ISFP  11928
# 14  ISTJ   9290
# 15  ISTP  15314

# %%
pip install pyecharts
# Out:
# Requirement already satisfied: pyecharts in /Users/rainerperry/opt/anaconda3/lib/python3.8/site-packages (1.9.0)
# Requirement already satisfied: prettytable in /Users/rainerperry/opt/anaconda3/lib/python3.8/site-packages (from pyecharts) (2.0.0)
# Requirement already satisfied: jinja2 in /Users/rainerperry/opt/anaconda3/lib/python3.8/site-packages (from pyecharts) (2.11.2)
# Requirement already satisfied: simplejson in /Users/rainerperry/opt/anaconda3/lib/python3.8/site-packages (from pyecharts) (3.17.2)
# Requirement already satisfied: setuptools in /Users/rainerperry/opt/anaconda3/lib/python3.8/site-packages (from prettytable->pyecharts) (49.2.0.post20200714)
# Requirement already satisfied: wcwidth in /Users/rainerperry/opt/anaconda3/lib/python3.8/site-packages (from prettytable->pyecharts) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/rainerperry/opt/anaconda3/lib/python3.8/site-packages (from jinja2->pyecharts) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.globals import ThemeType

bar = (
    Bar()
    .add_xaxis(['ENFJ','ENFP','ENTJ','ENTP','ESFJ','ESFP','ESTJ','ESTP','INFJ','INFP','INTJ','INTP','ISFJ','ISFP','ISTJ','ISTP'])
    .add_yaxis("Count", [8814,31112,10690,32071,1971,2087,1826,4084,67638,83569,49400,59144,7585,11928,9290,15314],color="#1565C0")
    .set_global_opts(title_opts=opts.TitleOpts(title="Frequency of Types", subtitle="Meyers Briggs Type Indicator"))
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
        markpoint_opts=opts.MarkPointOpts(
        data=[opts.MarkPointItem(type_="max", name="Highest Value"),
              opts.MarkPointItem(type_="min", name="Lowest Value"),]),
                )
                )


bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dc9ef64e85d545899ce67a780ae0d3e4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dc9ef64e85d545899ce67a780ae0d3e4 = echarts.init(
#                     document.getElementById('dc9ef64e85d545899ce67a780ae0d3e4'), 'white', {renderer: 'canvas'});
#                 var option_dc9ef64e85d545899ce67a780ae0d3e4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#1565C0",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Count",
#             "legendHoverLink": true,
#             "data": [
#                 8814,
#                 31112,
#                 10690,
#                 32071,
#                 1971,
#                 2087,
#                 1826,
#                 4084,
#                 67638,
#                 83569,
#                 49400,
#                 59144,
#                 7585,
#                 11928,
#                 9290,
#                 15314
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "Highest Value",
#                         "type": "max"
#                     },
#                     {
#                         "name": "Lowest Value",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Count"
#             ],
#             "selected": {
#                 "Count": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "ENFJ",
#                 "ENFP",
#                 "ENTJ",
#                 "ENTP",
#                 "ESFJ",
#                 "ESFP",
#                 "ESTJ",
#                 "ESTP",
#                 "INFJ",
#                 "INFP",
#                 "INTJ",
#                 "INTP",
#                 "ISFJ",
#                 "ISFP",
#                 "ISTJ",
#                 "ISTP"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Frequency of Types",
#             "subtext": "Meyers Briggs Type Indicator",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_dc9ef64e85d545899ce67a780ae0d3e4.setOption(option_dc9ef64e85d545899ce67a780ae0d3e4);
#         });
#     </script>

# %%
import mpld3

from mpld3 import fig_to_html, plugins, save_html

# mpld3.plugins.connect(fig, mpld3.plugins.LineLabelTooltip)


fig = bar.render_notebook()
html_str = mpld3.fig_to_html(fig)
# Html_file= open("image.html","w")
# Html_file.write(html_str)
# Html_file.close()

# if fig.canvas is None:
#     canvas = FigureCanvasAgg(fig)
#     fig.savefig(io.BytesIO(), format='png', dpi=fig.dpi)


    
    
# plt.savefig("bar.jpg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-8e5110fc9c00> in <module>
#       7
#       8 fig = bar.render_notebook()
# ----> 9 html_str = mpld3.fig_to_html(fig)
#      10 # Html_file= open("image.html","w")
#      11 # Html_file.write(html_str)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mpld3/_display.py in fig_to_html(fig, d3_url, mpld3_url, no_extras, template_type, figid, use_http, **kwargs)
#     241
#     242     renderer = MPLD3Renderer()
# --> 243     Exporter(renderer, close_mpl=False, **kwargs).run(fig)
#     244
#     245     fig, figure_json, extra_css, extra_js = renderer.finished_figures[0]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mpld3/mplexporter/exporter.py in run(self, fig)
#      43         # Calling savefig executes the draw() command, putting elements
#      44         # in the correct place.
# ---> 45         if fig.canvas is None:
#      46             canvas = FigureCanvasAgg(fig)
#      47         fig.savefig(io.BytesIO(), format='png', dpi=fig.dpi)
#
# AttributeError: 'HTML' object has no attribute 'canvas'

# %%
plt.savefig("bar.png")
